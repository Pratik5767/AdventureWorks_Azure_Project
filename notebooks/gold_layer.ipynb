# %%
spark.sql("CREATE SCHEMA IF NOT EXISTS gold")
# Out:
# StatementMeta(, 6c76bde3-ff38-4eb0-a61b-84cda8faef26, 42, Finished, Available, Finished, False)
# DataFrame[]

# %%
df_cal = spark.read.parquet("Files/silver/AdventureWorks_Calendar")

df_cal.write.format("delta") \
        .mode("overwrite") \
        .saveAsTable("gold.calender")
# Out:
# StatementMeta(, 6c76bde3-ff38-4eb0-a61b-84cda8faef26, 43, Finished, Available, Finished, False)

# %%
df = spark.sql("SELECT * FROM adventureworks_LH.gold.calender LIMIT 100")
display(df)
# Out:
# StatementMeta(, 6c76bde3-ff38-4eb0-a61b-84cda8faef26, 44, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 4dc56fe0-483b-40da-96bc-caf409fe863d)

# %%
df_cus = spark.read.parquet("Files/silver/AdventureWorks_Customers")

df_cus.write.format("delta") \
        .mode("overwrite") \
        .saveAsTable("gold.customer")
# Out:
# StatementMeta(, 6c76bde3-ff38-4eb0-a61b-84cda8faef26, 45, Finished, Available, Finished, False)

# %%
df = spark.sql("SELECT * FROM adventureworks_LH.gold.customer LIMIT 100")
display(df)
# Out:
# StatementMeta(, 6c76bde3-ff38-4eb0-a61b-84cda8faef26, 46, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, cd0e065a-c457-4fee-911f-481a2b2d65ee)

# %%
df_prod_cat = spark.read.parquet("Files/silver/AdventureWorks_Product_Categories")

df_prod_cat.write.format("delta") \
        .mode("overwrite") \
        .saveAsTable("gold.product_category")
# Out:
# StatementMeta(, 6c76bde3-ff38-4eb0-a61b-84cda8faef26, 47, Finished, Available, Finished, False)

# %%
df = spark.sql("SELECT * FROM adventureworks_LH.gold.product_category LIMIT 100")
display(df)
# Out:
# StatementMeta(, 6c76bde3-ff38-4eb0-a61b-84cda8faef26, 48, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, cb87dedf-d001-4486-86eb-d47a12430ad7)

# %%
df_prod = spark.read.parquet("Files/silver/AdventureWorks_Products")

df_prod.write.format("delta") \
        .mode("overwrite") \
        .saveAsTable("gold.product")
# Out:
# StatementMeta(, 6c76bde3-ff38-4eb0-a61b-84cda8faef26, 49, Finished, Available, Finished, False)

# %%
df = spark.sql("SELECT * FROM adventureworks_LH.gold.product LIMIT 100")
display(df)
# Out:
# StatementMeta(, 6c76bde3-ff38-4eb0-a61b-84cda8faef26, 50, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, ce4e172e-faa9-4ebf-99ce-f0f75e5f554e)

# %%
df_ret = spark.read.parquet("Files/silver/AdventureWorks_Returns")

df_ret.write.format("delta") \
        .mode("overwrite") \
        .saveAsTable("gold.returns")
# Out:
# StatementMeta(, 6c76bde3-ff38-4eb0-a61b-84cda8faef26, 51, Finished, Available, Finished, False)

# %%
df = spark.sql("SELECT * FROM adventureworks_LH.gold.returns LIMIT 100")
display(df)
# Out:
# StatementMeta(, 6c76bde3-ff38-4eb0-a61b-84cda8faef26, 52, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 02019a0a-f715-4008-9a82-a9dfba4d6f55)

# %%
df_terr = spark.read.parquet("Files/silver/AdventureWorks_Territories")

df_terr.write.format("delta") \
        .mode("overwrite") \
        .saveAsTable("gold.territories")
# Out:
# StatementMeta(, 6c76bde3-ff38-4eb0-a61b-84cda8faef26, 53, Finished, Available, Finished, False)

# %%
df = spark.sql("SELECT * FROM adventureworks_LH.gold.territories LIMIT 100")
display(df)
# Out:
# StatementMeta(, 6c76bde3-ff38-4eb0-a61b-84cda8faef26, 54, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 79bd4411-b785-43b1-99a7-629be89ee019)

# %%
df_subcat = spark.read.parquet("Files/silver/Product_Subcategories")

df_subcat.write.format("delta") \
        .mode("overwrite") \
        .saveAsTable("gold.subcategories")
# Out:
# StatementMeta(, 6c76bde3-ff38-4eb0-a61b-84cda8faef26, 55, Finished, Available, Finished, False)

# %%
df = spark.sql("SELECT * FROM adventureworks_LH.gold.subcategories LIMIT 100")
display(df)
# Out:
# StatementMeta(, 6c76bde3-ff38-4eb0-a61b-84cda8faef26, 56, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 078ca429-8a21-4d74-b2d8-fc1ce8931c7f)

# %%
df_sales = spark.read.parquet("Files/silver/AdventureWorks_Sales")

df_sales.write.format("delta") \
        .mode("overwrite") \
        .saveAsTable("gold.sales")
# Out:
# StatementMeta(, 6c76bde3-ff38-4eb0-a61b-84cda8faef26, 57, Finished, Available, Finished, False)

# %%
df = spark.sql("SELECT * FROM adventureworks_LH.gold.sales LIMIT 100")
display(df)
# Out:
# StatementMeta(, 6c76bde3-ff38-4eb0-a61b-84cda8faef26, 58, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 18a7a856-b5fb-4543-a703-7e750373dc65)
